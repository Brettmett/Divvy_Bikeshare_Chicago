# %% [markdown]
# # Goal: For every Trip in 2022, i want to identify the community area the trip started and where it ended and add this information to the trips data.
#
# How?
#  1. For every trip, take "start_lat" and "start_lon", and create a Geometrical Point
#  2. Do the Same thing with end_lat and end_lon.
#  3. Use community districts Polygon data (see notebook 01_get_geodata_districts_chicago.ipynb) and perform a spatial join, to match points (start/end)  and polygons (districts).

# %% [markdown]
# ## Importing Packages

# %%
# pandas
import pandas as pd

# additional import of the geopandas package
import geopandas as gpd

# numpy
import numpy as np

# import mathplotlib.pyplot as plt
import matplotlib.pyplot as plt

# shapely.geometry      Package shapely.geomerty is usefull to for checking, weather a oint is inside a polygon and converting string type
from shapely import wkt
from shapely.geometry import Polygon, LineString, Point, MultiLineString

# importing self made functions from sql_functions script
import sql_functions as sf

# %% [markdown]
# ## Loading Trips 2022 (see notebook 01_get_trip_data.ipynb) from SQL Database:

# %%
# constants:
path = "data/"
schema = "capstone_divvy_bikeshare"
engine = sf.get_engine()

# %%
# Loading from SQL Database. Lets just load a random Set of 500.000 Trips out of the 
df_22 = sf.get_dataframe(f"SELECT * From {schema}.trips_2022_v2 ORDER BY RANDOM() LIMIT 500000")

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ride_id                  500000 non-null  object
#  1   rideable_type            500000 non-null  object
#  2   starttime                500000 non-null  datetime64[ns]
#  3   stoptime                 500000 non-null  datetime64[ns]
#  4   from_station_id          500000 non-null  object
#  5   from_station_name        427663 non-null  object
#  6   to_station_id            500000 non-null  object
#  7   to_station_name          423118 non-null  object
#  8   start_lat                500000 non-null  float64
#  9   start_lng                500000 non-null  float64
#  10  end_lat                  499488 non-null  float64
#  11  end_lng                  499488 non-null  float64
#  12  member_casual            500000 non-null  object
#  13  time_difference_seconds  500000 non-null  int64
#  14  tripduration_in_min      500000 non-null  float64
#  15  trip_value               500000 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(7)
# memory usage: 61.0+ MB

# %%
df_22.head()
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  6E70D9613415920B   classic_bike 2022-07-02 23:12:16 2022-07-02 23:34:49
# 1  BCCC831F5A02BCF0  electric_bike 2022-10-23 06:39:05 2022-10-23 06:44:30
# 2  29A0386C1A150B87  electric_bike 2022-04-08 11:22:48 2022-04-08 11:40:03
# 3  C88D44706B5D3AD0   classic_bike 2022-04-15 07:15:35 2022-04-15 07:31:09
# 4  B39728DFDD3698C6   classic_bike 2022-02-13 12:59:18 2022-02-13 13:16:28
#
#   from_station_id               from_station_name to_station_id  \
# 0           13430        LaSalle St & Illinois St  TA1307000038
# 1               0                            None         18003
# 2           13084  California Ave & Milwaukee Ave             0
# 3    TA1306000006             Orleans St & Elm St  TA1305000006
# 4          SL-005      Indiana Ave & Roosevelt Rd         15539
#
#                 to_station_name  start_lat  start_lng    end_lat    end_lng  \
# 0       Sedgwick St & North Ave  41.890762 -87.631697  41.911386 -87.638677
# 1    Fairbanks St & Superior St  41.890000 -87.630000  41.895748 -87.620104
# 2                          None  41.922637 -87.697089  41.920000 -87.760000
# 3       Dearborn St & Monroe St  41.902924 -87.637715  41.881320 -87.629521
# 4  Desplaines St & Jackson Blvd  41.867888 -87.623041  41.878119 -87.643948
#
#   member_casual  time_difference_seconds  tripduration_in_min  trip_value
# 0        casual                     1353            22.550000    4.833500
# 1        member                      325             5.416667    0.920833
# 2        casual                     1035            17.250000    8.245000
# 3        member                      934            15.566667    0.000000
# 4        casual                     1030            17.166667    3.918333

# %% [markdown]
# ## 1./2. For every trip, take "start_lat" and "start_lon", and create a Geometrical Point

# %% [markdown]
# #### Creating GeoDataFrame:
#     * using latitude and longitude to create a geometry POINT
#     * for this use: gpd.points_from_xy() Function
#     help: https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html

# %% [markdown]
# ### Dealing with NaN Values in the start_lat, start_lng end_lat,end_lng columns:

# %%
# NaN values in end_lat:
df_22["end_lat"].isna().value_counts()
# Out:
# False    499488
# True        512
# Name: end_lat, dtype: int64

# %%
# NaN values in end lng:
df_22["end_lng"].isna().value_counts()
# Out:
# False    499488
# True        512
# Name: end_lng, dtype: int64

# %%
# NaN values in start_lat:
df_22["start_lat"].isna().value_counts()
# Out:
# False    500000
# Name: start_lat, dtype: int64

# %%
# NaN values in start_lng:
df_22["start_lng"].isna().value_counts()
# Out:
# False    500000
# Name: start_lng, dtype: int64

# %% [markdown]
# Lets drop all rows with NaN values in the end_lat and end_lng columns:

# %%
# Dropping all rows, where column "end_lat" has NaN value:
df_22.dropna(axis=0, subset="end_lat", inplace= True)

# %% [markdown]
# As we can see, we dont have any NaN values in the Columns:  rows have been deleted:

# %%
df_22["end_lat"].isna().value_counts()
# Out:
# False    499488
# Name: end_lat, dtype: int64

# %% [markdown]
# Now, that all Trips have start lat/lon and end lat/lon, lets create point geometries:

# %%
# creating a geodataframe by combining start_lat and start_long to "start_point" geometry columns, crs = WGS 84 
gdf_22_start = gpd.GeoDataFrame(df_22, crs="WGS 84", geometry= gpd.points_from_xy(df_22["start_lng"],df_22["start_lat"])).rename(columns={"geometry":"start_point"})
# now use the created gdf_22_start Geodataframe and add endpoint
gdf_22 = gpd.GeoDataFrame(gdf_22_start,crs="WGS 84", geometry= gpd.points_from_xy(gdf_22_start["end_lng"],gdf_22_start["end_lat"])).rename(columns={"geometry":"end_point"})

# %%
gdf_22["start_point"].sample(10000, random_state=42).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5d9afc55dd732ec00e950a125b653d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5d9afc55dd732ec00e950a125b653d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5d9afc55dd732ec00e950a125b653d9 = L.map(
#                 &quot;map_b5d9afc55dd732ec00e950a125b653d9&quot;,
#                 {
#                     center: [41.86, -87.68021557569503],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b5d9afc55dd732ec00e950a125b653d9);
#
#
#
#
#
#             var tile_layer_238fffafaaa2d9953349d3501d3934a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5d9afc55dd732ec00e950a125b653d9);
#
#
#             map_b5d9afc55dd732ec00e950a125b653d9.fitBounds(
#                 [[41.65, -87.83], [42.07, -87.53043115139008]],
#                 {}
#             );
#
#
#         function geo_json_59f6fe49870b761b5223f871f0235d63_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_59f6fe49870b761b5223f871f0235d63_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_59f6fe49870b761b5223f871f0235d63_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_59f6fe49870b761b5223f871f0235d63_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_59f6fe49870b761b5223f871f0235d63_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_59f6fe49870b761b5223f871f0235d63.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_59f6fe49870b761b5223f871f0235d63_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_59f6fe49870b761b5223f871f0235d63 = L.geoJson(null, {
#                 onEachFeature: geo_json_59f6fe49870b761b5223f871f0235d63_onEachFeature,
#
#                 style: geo_json_59f6fe49870b761b5223f871f0235d63_styler,
#                 pointToLayer: geo_json_59f6fe49870b761b5223f871f0235d63_pointToLayer
#         });
#
#         function geo_json_59f6fe49870b761b5223f871f0235d63_add (data) {
#             geo_json_59f6fe49870b761b5223f871f0235d63
#                 .addData(data)
#                 .addTo(map_b5d9afc55dd732ec00e950a125b653d9);
#         }
#             geo_json_59f6fe49870b761b5223f871f0235d63_add({&quot;bbox&quot;: [-87.83, 41.65, -87.53043115139008, 42.07], &quot;features&quot;: [{&quot;bbox&quot;: [-87.6687, 41.950687, -87.6687, 41.950687], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.6687, 41.950687], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;309302&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.686234, 41.868563, -87.686234, 41.868563], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.686234, 41.868563], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;76421&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.664117, 41.94818133333333, -87.664117, 41.94818133333333], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.664117, 41.94818133333333], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;377247&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.67688512802124, 41.892394452962705, -87.67688512802124, 41.892394452962705], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.67688512802124, 41.892394452962705], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;232305&quot;, &quot;properties

# %% [markdown]
# As we can see, we added two new geometry columns "start_point" and "end_point to the gdf_22 Geodataframe:

# %%
gdf_22.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 499488 entries, 0 to 499999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ride_id                  499488 non-null  object
#  1   rideable_type            499488 non-null  object
#  2   starttime                499488 non-null  datetime64[ns]
#  3   stoptime                 499488 non-null  datetime64[ns]
#  4   from_station_id          499488 non-null  object
#  5   from_station_name        427151 non-null  object
#  6   to_station_id            499488 non-null  object
#  7   to_station_name          423118 non-null  object
#  8   start_lat                499488 non-null  float64
#  9   start_lng                499488 non-null  float64
#  10  end_lat                  499488 non-null  float64
#  11  end_lng                  499488 non-null  float64
#  12  member_casual            499488 non-null  object
#  13  time_difference_seconds  499488 non-null  int64
#  14  tripduration_in_min      499488 non-null  float64
#  15  trip_value               499488 non-null  float64
#  16  start_point              499488 non-null  geometry
#  17  end_point                499488 non-null  geometry
# dtypes: datetime64[ns](2), float64(6), geometry(2), int64(1), object(7)
# memory usage: 72.4+ MB

# %% [markdown]
# ## 3. Lets use the table we created in Notebook 01_get_geodata_districts_chicago.ipynb

# %%
# loading table with the area geometries created in Notebook 01_get_geodata_districts_chicago.ipynb
df_areas = pd.read_csv("data/clean_areas.csv")
df_areas.head(2)
# Out:
#    Unnamed: 0  area_number community_name    shape_area     shape_len  \
# 0           9            1    Rogers Park  5.125990e+07  34052.397576
# 1          19            2     West Ridge  9.842909e+07  43020.689458
#
#                                         new_geometry
# 0  MULTIPOLYGON (((-87.65455590025104 41.99816614...
# 1  MULTIPOLYGON (((-87.6846530946559 42.019484772...

# %%
# converting to GeoDataFrame by using self made function
gdf_areas = sf.to_gdf(df_areas,geometry_column="new_geometry")

# %%
gdf_areas.head()
# Out:
#    Unnamed: 0  area_number  community_name    shape_area     shape_len  \
# 0           9            1     Rogers Park  5.125990e+07  34052.397576
# 1          19            2      West Ridge  9.842909e+07  43020.689458
# 2          30            3          Uptown  6.509564e+07  46972.794555
# 3           5            4  Lincoln Square  7.135233e+07  36624.603085
# 4          47            5    North Center  5.705417e+07  31391.669754
#
#                                         new_geometry
# 0  MULTIPOLYGON (((-87.65456 41.99817, -87.65574 ...
# 1  MULTIPOLYGON (((-87.68465 42.01948, -87.68464 ...
# 2  MULTIPOLYGON (((-87.64102 41.95480, -87.64400 ...
# 3  MULTIPOLYGON (((-87.67441 41.97610, -87.67440 ...
# 4  MULTIPOLYGON (((-87.67336 41.93234, -87.67342 ...

# %% [markdown]
# #### Now lets add the columns start_area_number and end_area_number, for every Trip by performing a spatial Join:

# %% [markdown]
# #### Spatial Join on Start Points

# %%
# setting start_point as gemoetry, so that the starting points are checked (whether they are inside of a district)
gdf_22.set_geometry("start_point", inplace=True)

# %%
# Perform spatial join to match start_points and polygons
gdf_22_merge1 = gpd.tools.sjoin(gdf_22, gdf_areas[["area_number","community_name","new_geometry"]], predicate="within", how='left')

# %% [markdown]
# Renaming the columns "area_number" and "community_name" to "start_area_number" and "start_community_name":

# %%
gdf_22_merge1.rename(columns={"area_number":"start_area_number", "community_name":"start_community_name"},inplace=True)

# %%
gdf_22_merge1.head()
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  6E70D9613415920B   classic_bike 2022-07-02 23:12:16 2022-07-02 23:34:49
# 1  BCCC831F5A02BCF0  electric_bike 2022-10-23 06:39:05 2022-10-23 06:44:30
# 2  29A0386C1A150B87  electric_bike 2022-04-08 11:22:48 2022-04-08 11:40:03
# 3  C88D44706B5D3AD0   classic_bike 2022-04-15 07:15:35 2022-04-15 07:31:09
# 4  B39728DFDD3698C6   classic_bike 2022-02-13 12:59:18 2022-02-13 13:16:28
#
#   from_station_id               from_station_name to_station_id  \
# 0           13430        LaSalle St & Illinois St  TA1307000038
# 1               0                            None         18003
# 2           13084  California Ave & Milwaukee Ave             0
# 3    TA1306000006             Orleans St & Elm St  TA1305000006
# 4          SL-005      Indiana Ave & Roosevelt Rd         15539
#
#                 to_station_name  start_lat  start_lng  ...    end_lng  \
# 0       Sedgwick St & North Ave  41.890762 -87.631697  ... -87.638677
# 1    Fairbanks St & Superior St  41.890000 -87.630000  ... -87.620104
# 2                          None  41.922637 -87.697089  ... -87.760000
# 3       Dearborn St & Monroe St  41.902924 -87.637715  ... -87.629521
# 4  Desplaines St & Jackson Blvd  41.867888 -87.623041  ... -87.643948
#
#    member_casual time_difference_seconds  tripduration_in_min  trip_value  \
# 0         casual                    1353            22.550000    4.833500
# 1         member                     325             5.416667    0.920833
# 2         casual                    1035            17.250000    8.245000
# 3         member                     934            15.566667    0.000000
# 4         casual                    1030            17.166667    3.918333
#
#                   start_point                   end_point index_right  \
# 0  POINT (-87.63170 41.89076)  POINT (-87.63868 41.91139)         7.0
# 1  POINT (-87.63000 41.89000)  POINT (-87.62010 41.89575)         7.0
# 2  POINT (-87.69709 41.92264)  POINT (-87.76000 41.92000)        21.0
# 3  POINT (-87.63772 41.90292)  POINT (-87.62952 41.88132)         7.0
# 4  POINT (-87.62304 41.86789)  POINT (-87.64395 41.87812)        31.0
#
#    start_area_number  start_community_name
# 0                8.0       Near North Side
# 1                8.0       Near North Side
# 2               22.0          Logan Square
# 3                8.0       Near North Side
# 4               32.0                  Loop
#
# [5 rows x 21 columns]

# %%
# droping "index_right" column
gdf_22_merge1.drop(columns="index_right",inplace=True)

# %%
# setting end_point as gemoetry, so that the ending points are checked (are they inside of a district (Polygon))
gdf_22_merge1.set_geometry("end_point", inplace=True)

# %%
# Perform spatial join to match points (this time end points)  and polygons (districts)
gdf_22_merge2 = gpd.tools.sjoin(gdf_22_merge1, gdf_areas[["area_number","community_name","new_geometry"]], predicate="within", how='left')

# %%
gdf_22_merge2.head()
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  6E70D9613415920B   classic_bike 2022-07-02 23:12:16 2022-07-02 23:34:49
# 1  BCCC831F5A02BCF0  electric_bike 2022-10-23 06:39:05 2022-10-23 06:44:30
# 2  29A0386C1A150B87  electric_bike 2022-04-08 11:22:48 2022-04-08 11:40:03
# 3  C88D44706B5D3AD0   classic_bike 2022-04-15 07:15:35 2022-04-15 07:31:09
# 4  B39728DFDD3698C6   classic_bike 2022-02-13 12:59:18 2022-02-13 13:16:28
#
#   from_station_id               from_station_name to_station_id  \
# 0           13430        LaSalle St & Illinois St  TA1307000038
# 1               0                            None         18003
# 2           13084  California Ave & Milwaukee Ave             0
# 3    TA1306000006             Orleans St & Elm St  TA1305000006
# 4          SL-005      Indiana Ave & Roosevelt Rd         15539
#
#                 to_station_name  start_lat  start_lng  ...  \
# 0       Sedgwick St & North Ave  41.890762 -87.631697  ...
# 1    Fairbanks St & Superior St  41.890000 -87.630000  ...
# 2                          None  41.922637 -87.697089  ...
# 3       Dearborn St & Monroe St  41.902924 -87.637715  ...
# 4  Desplaines St & Jackson Blvd  41.867888 -87.623041  ...
#
#    time_difference_seconds  tripduration_in_min trip_value  \
# 0                     1353            22.550000   4.833500
# 1                      325             5.416667   0.920833
# 2                     1035            17.250000   8.245000
# 3                      934            15.566667   0.000000
# 4                     1030            17.166667   3.918333
#
#                   start_point                   end_point  start_area_number  \
# 0  POINT (-87.63170 41.89076)  POINT (-87.63868 41.91139)                8.0
# 1  POINT (-87.63000 41.89000)  POINT (-87.62010 41.89575)                8.0
# 2  POINT (-87.69709 41.92264)  POINT (-87.76000 41.92000)               22.0
# 3  POINT (-87.63772 41.90292)  POINT (-87.62952 41.88132)                8.0
# 4  POINT (-87.62304 41.86789)  POINT (-87.64395 41.87812)               32.0
#
#   start_community_name index_right  area_number   community_name
# 0      Near North Side         6.0          7.0     Lincoln Park
# 1      Near North Side         7.0          8.0  Near North Side
# 2         Logan Square        18.0         19.0   Belmont Cragin
# 3      Near North Side        31.0         32.0             Loop
# 4                 Loop        27.0         28.0   Near West Side
#
# [5 rows x 23 columns]

# %% [markdown]
# Renaming the columns "area_number" and "community_name" to "start_area_number" and "start_community_name":

# %%
# renaming columns:
gdf_22_merge2.rename(columns={"area_number":"end_area_number", "community_name":"end_community_name"},inplace=True)
gdf_22_merge2.head(4)
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  6E70D9613415920B   classic_bike 2022-07-02 23:12:16 2022-07-02 23:34:49
# 1  BCCC831F5A02BCF0  electric_bike 2022-10-23 06:39:05 2022-10-23 06:44:30
# 2  29A0386C1A150B87  electric_bike 2022-04-08 11:22:48 2022-04-08 11:40:03
# 3  C88D44706B5D3AD0   classic_bike 2022-04-15 07:15:35 2022-04-15 07:31:09
#
#   from_station_id               from_station_name to_station_id  \
# 0           13430        LaSalle St & Illinois St  TA1307000038
# 1               0                            None         18003
# 2           13084  California Ave & Milwaukee Ave             0
# 3    TA1306000006             Orleans St & Elm St  TA1305000006
#
#               to_station_name  start_lat  start_lng  ...  \
# 0     Sedgwick St & North Ave  41.890762 -87.631697  ...
# 1  Fairbanks St & Superior St  41.890000 -87.630000  ...
# 2                        None  41.922637 -87.697089  ...
# 3     Dearborn St & Monroe St  41.902924 -87.637715  ...
#
#    time_difference_seconds  tripduration_in_min trip_value  \
# 0                     1353            22.550000   4.833500
# 1                      325             5.416667   0.920833
# 2                     1035            17.250000   8.245000
# 3                      934            15.566667   0.000000
#
#                   start_point                   end_point  start_area_number  \
# 0  POINT (-87.63170 41.89076)  POINT (-87.63868 41.91139)                8.0
# 1  POINT (-87.63000 41.89000)  POINT (-87.62010 41.89575)                8.0
# 2  POINT (-87.69709 41.92264)  POINT (-87.76000 41.92000)               22.0
# 3  POINT (-87.63772 41.90292)  POINT (-87.62952 41.88132)                8.0
#
#   start_community_name index_right  end_area_number end_community_name
# 0      Near North Side         6.0              7.0       Lincoln Park
# 1      Near North Side         7.0              8.0    Near North Side
# 2         Logan Square        18.0             19.0     Belmont Cragin
# 3      Near North Side        31.0             32.0               Loop
#
# [4 rows x 23 columns]

# %%
# droping "index_right" column
gdf_22_merge2.drop(columns="index_right",inplace=True)

# %% [markdown]
# #### Dealing with NaN Values:
#     - Problem: there are some trips, where we have NaN Values for start and end community area numbers and names. Lets look at them:

# %%
# NaN Values in start_area_number:
gdf_22_merge2["start_area_number"].isna().value_counts()
# Out:
# False    496835
# True       2653
# Name: start_area_number, dtype: int64

# %%
gdf_22_merge2["end_area_number"].isna().value_counts()
# Out:
# False    496489
# True       2999
# Name: end_area_number, dtype: int64

# %% [markdown]
# #### Since we made sure, that all Trips had a start and endpoint, NaN Values in the end_area_number/start_area_number mean, that these trips ended/started outside of the the areas of Divvy. Lets deal with the NaN Values, the following way:
#     - If start_area_number = NaN         ---> 999
#     - If start_community_name = Nan      ---> "not in districts"
#     - end_area_number = NaN              ---> 999
#     - end_community_name                 ---> "not in districts"

# %%
# replacing NaN Values:
gdf_22_merge2["start_area_number"].fillna(999, inplace=True)
gdf_22_merge2["end_area_number"].fillna(999, inplace=True)
gdf_22_merge2["start_community_name"].fillna("not in districts", inplace=True)
gdf_22_merge2["end_community_name"].fillna("not in districts", inplace=True)

# %% [markdown]
# As we can see, there are no more NaN values in those columns:

# %%
gdf_22_merge2["end_area_number"].isna().value_counts()
# Out:
# False    499488
# Name: end_area_number, dtype: int64

# %%
# converting start_area_number and end_area_number from float to integer:
gdf_22_merge2["start_area_number"] = gdf_22_merge2["start_area_number"].astype(int)
gdf_22_merge2["end_area_number"] = gdf_22_merge2["end_area_number"].astype(int)

# %%
gdf_22_merge2.head(1)
# Out:
#             ride_id rideable_type           starttime            stoptime  \
# 0  6E70D9613415920B  classic_bike 2022-07-02 23:12:16 2022-07-02 23:34:49
#
#   from_station_id         from_station_name to_station_id  \
# 0           13430  LaSalle St & Illinois St  TA1307000038
#
#            to_station_name  start_lat  start_lng  ...  member_casual  \
# 0  Sedgwick St & North Ave  41.890762 -87.631697  ...         casual
#
#    time_difference_seconds tripduration_in_min  trip_value  \
# 0                     1353               22.55      4.8335
#
#                   start_point                   end_point start_area_number  \
# 0  POINT (-87.63170 41.89076)  POINT (-87.63868 41.91139)                 8
#
#   start_community_name  end_area_number end_community_name
# 0      Near North Side                7       Lincoln Park
#
# [1 rows x 22 columns]

# %% [markdown]
# #### All ending Locations for Trips, which have ended outside of chicago districts:

# %%
gdf_22_merge2[gdf_22_merge2["end_area_number"]==999]["end_point"].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c5765a6e05b29e1fe76ba00f7bedc1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c5765a6e05b29e1fe76ba00f7bedc1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c5765a6e05b29e1fe76ba00f7bedc1f = L.map(
#                 &quot;map_7c5765a6e05b29e1fe76ba00f7bedc1f&quot;,
#                 {
#                     center: [21.05, -43.965],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7c5765a6e05b29e1fe76ba00f7bedc1f);
#
#
#
#
#
#             var tile_layer_04e762bad397dac57eca8f75a5bd7fe3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c5765a6e05b29e1fe76ba00f7bedc1f);
#
#
#             map_7c5765a6e05b29e1fe76ba00f7bedc1f.fitBounds(
#                 [[0.0, -87.93], [42.1, 0.0]],
#                 {}
#             );
#
#
#         function geo_json_9d2a9feafd16f5f75fc20997a17f98e6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9d2a9feafd16f5f75fc20997a17f98e6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9d2a9feafd16f5f75fc20997a17f98e6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_9d2a9feafd16f5f75fc20997a17f98e6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9d2a9feafd16f5f75fc20997a17f98e6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_9d2a9feafd16f5f75fc20997a17f98e6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9d2a9feafd16f5f75fc20997a17f98e6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9d2a9feafd16f5f75fc20997a17f98e6 = L.geoJson(null, {
#                 onEachFeature: geo_json_9d2a9feafd16f5f75fc20997a17f98e6_onEachFeature,
#
#                 style: geo_json_9d2a9feafd16f5f75fc20997a17f98e6_styler,
#                 pointToLayer: geo_json_9d2a9feafd16f5f75fc20997a17f98e6_pointToLayer
#         });
#
#         function geo_json_9d2a9feafd16f5f75fc20997a17f98e6_add (data) {
#             geo_json_9d2a9feafd16f5f75fc20997a17f98e6
#                 .addData(data)
#                 .addTo(map_7c5765a6e05b29e1fe76ba00f7bedc1f);
#         }
#             geo_json_9d2a9feafd16f5f75fc20997a17f98e6_add({&quot;bbox&quot;: [-87.93, 0.0, 0.0, 42.1], &quot;features&quot;: [{&quot;bbox&quot;: [-87.62, 41.91, -87.62, 41.91], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.62, 41.91], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;9&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.62, 41.91, -87.62, 41.91], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.62, 41.91], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;68&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.62, 41.91, -87.62, 41.91], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.62, 41.91], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;292&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.62, 41.91, -87.62, 41.91], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.62, 41.91], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;611&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.63, 41.93, -87.63, 41.93], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.63, 41.93], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quo
