# %% [markdown]
# # Goal: For every Trip in 2022, i want to identify the community area the trip started in and where it ended. Then, i want to add this information to the trips table.
#
# How?
#  1. For every trip, take "start_lat" and "start_lon", and create a Geometrical Point
#  2. Do the same thing with end_lat and end_lon.
#  3. Use community districts Polygon data (see notebook 01_get_geodata_districts_chicago.ipynb)
#  4. Perform a spatial join, to match points (start/end)  and polygons (districts).
#  5. Upload to Sql DataBase

# %% [markdown]
# ## Importing Packages

# %%
# pandas
import pandas as pd

# additional import of the geopandas package
import geopandas as gpd

# numpy
import numpy as np

# import mathplotlib.pyplot as plt
import matplotlib.pyplot as plt

# shapely.geometry      Package shapely.geomerty is usefull to for checking, weather a oint is inside a polygon and converting string type
from shapely import wkt
from shapely.geometry import Polygon, LineString, Point, MultiLineString

# importing self made functions from sql_functions script
import sql_functions as sf

# %% [markdown]
# ## Loading Trips 2022 (see notebook 01_get_trip_data.ipynb) from SQL Database:

# %%
# constants:
path = "data/"
schema = "capstone_divvy_bikeshare"
engine = sf.get_engine()

# %%
# Loading from SQL Database. Lets just load a random Set of 500.000 Trips out of more than 5 million to show the code
df_22 = sf.get_dataframe(f"SELECT * From {schema}.trips_2022_v2 ORDER BY RANDOM() LIMIT 500000")
#df_22 = sf.get_dataframe(f"SELECT * From {schema}.trips_2022_v2")

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ride_id                  500000 non-null  object
#  1   rideable_type            500000 non-null  object
#  2   starttime                500000 non-null  datetime64[ns]
#  3   stoptime                 500000 non-null  datetime64[ns]
#  4   from_station_id          500000 non-null  object
#  5   from_station_name        428179 non-null  object
#  6   to_station_id            500000 non-null  object
#  7   to_station_name          423340 non-null  object
#  8   start_lat                500000 non-null  float64
#  9   start_lng                500000 non-null  float64
#  10  end_lat                  499470 non-null  float64
#  11  end_lng                  499470 non-null  float64
#  12  member_casual            500000 non-null  object
#  13  time_difference_seconds  500000 non-null  int64
#  14  tripduration_in_min      500000 non-null  float64
#  15  trip_value               500000 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(7)
# memory usage: 61.0+ MB

# %%
df_22.head()
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  9B632EBA1CC3202B  electric_bike 2022-12-07 07:34:57 2022-12-07 07:39:48
# 1  B20C4D0B45751662  electric_bike 2022-04-27 17:09:01 2022-04-27 17:20:53
# 2  F90780236FB6EC9E   classic_bike 2022-06-03 15:31:03 2022-06-03 15:36:42
# 3  98B2B077FE0AFE33  electric_bike 2022-08-29 17:15:10 2022-08-29 17:36:03
# 4  D396D97F3616E948  electric_bike 2022-04-20 07:46:45 2022-04-20 07:50:55
#
#   from_station_id              from_station_name to_station_id  \
# 0    TA1309000019  Lakeview Ave & Fullerton Pkwy             0
# 1             316        Lamon Ave & Belmont Ave             0
# 2           13001   Michigan Ave & Washington St         13008
# 3           13409  Sangamon St & Washington Blvd         20247
# 4          SL-010  Financial Pl & Ida B Wells Dr  TA1309000007
#
#                    to_station_name  start_lat  start_lng    end_lat  \
# 0                             None  41.925656 -87.639104  41.920000
# 1                             None  41.940000 -87.750000  41.930000
# 2                  Millennium Park  41.883984 -87.624684  41.881032
# 3  W Washington Blvd & N Peoria St  41.882971 -87.650839  41.880000
# 4          Franklin St & Monroe St  41.875046 -87.633116  41.880317
#
#      end_lng member_casual  time_difference_seconds  tripduration_in_min  \
# 0 -87.640000        member                      291             4.850000
# 1 -87.720000        casual                      712            11.866667
# 2 -87.624084        casual                      339             5.650000
# 3 -87.650000        member                     1253            20.883333
# 4 -87.635185        casual                      250             4.166667
#
#    trip_value
# 0    0.824500
# 1    5.984000
# 2    1.960500
# 3    3.550167
# 4    2.750000

# %% [markdown]
# ## 1./2. For every trip, take "start_lat" and "start_lon", and create a Geometrical Point

# %% [markdown]
# #### Creating GeoDataFrame:
#     * using latitude and longitude to create a geometry POINT
#     * for this use: gpd.points_from_xy() Function
#     help: https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html

# %% [markdown]
# ### Dealing with NaN Values in the start_lat, start_lng end_lat,end_lng columns:

# %%
# NaN values in end_lat:
df_22["end_lat"].isna().value_counts()
# Out:
# False    499470
# True        530
# Name: end_lat, dtype: int64

# %%
# NaN values in end lng:
df_22["end_lng"].isna().value_counts()
# Out:
# False    499470
# True        530
# Name: end_lng, dtype: int64

# %%
# NaN values in start_lat:
df_22["start_lat"].isna().value_counts()
# Out:
# False    500000
# Name: start_lat, dtype: int64

# %%
# NaN values in start_lng:
df_22["start_lng"].isna().value_counts()
# Out:
# False    500000
# Name: start_lng, dtype: int64

# %% [markdown]
# Lets drop all rows with NaN values in the end_lat and end_lng columns:

# %%
# Dropping all rows, where column "end_lat" has NaN value:
df_22.dropna(axis=0, subset="end_lat", inplace= True)

# %% [markdown]
# As we can see, we dont have any NaN values in the Columns:  rows have been deleted:

# %%
df_22["end_lat"].isna().value_counts()
# Out:
# False    499470
# Name: end_lat, dtype: int64

# %% [markdown]
# Now, that all Trips have start lat/lon and end lat/lon, lets create point geometries:

# %%
# creating a geodataframe by combining start_lat and start_long to "start_point" geometry columns, crs = WGS 84 
gdf_22_start = gpd.GeoDataFrame(df_22, crs="WGS 84", geometry= gpd.points_from_xy(df_22["start_lng"],df_22["start_lat"])).rename(columns={"geometry":"start_point"})
# now use the created gdf_22_start Geodataframe and add endpoint
gdf_22 = gpd.GeoDataFrame(gdf_22_start,crs="WGS 84", geometry= gpd.points_from_xy(gdf_22_start["end_lng"],gdf_22_start["end_lat"])).rename(columns={"geometry":"end_point"})

# %%
gdf_22["start_point"].sample(10000, random_state=42).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9421c964426807c99638fd69a882deea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9421c964426807c99638fd69a882deea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9421c964426807c99638fd69a882deea = L.map(
#                 &quot;map_9421c964426807c99638fd69a882deea&quot;,
#                 {
#                     center: [41.85659716666667, -87.68021557569503],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9421c964426807c99638fd69a882deea);
#
#
#
#
#
#             var tile_layer_861c59c0e8c362a17278481d76c20633 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9421c964426807c99638fd69a882deea);
#
#
#             map_9421c964426807c99638fd69a882deea.fitBounds(
#                 [[41.648501, -87.83], [42.06469333333333, -87.53043115139008]],
#                 {}
#             );
#
#
#         function geo_json_dedb2b63ad88f11245b29d7537c2929d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_dedb2b63ad88f11245b29d7537c2929d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_dedb2b63ad88f11245b29d7537c2929d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_dedb2b63ad88f11245b29d7537c2929d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_dedb2b63ad88f11245b29d7537c2929d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_dedb2b63ad88f11245b29d7537c2929d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_dedb2b63ad88f11245b29d7537c2929d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_dedb2b63ad88f11245b29d7537c2929d = L.geoJson(null, {
#                 onEachFeature: geo_json_dedb2b63ad88f11245b29d7537c2929d_onEachFeature,
#
#                 style: geo_json_dedb2b63ad88f11245b29d7537c2929d_styler,
#                 pointToLayer: geo_json_dedb2b63ad88f11245b29d7537c2929d_pointToLayer
#         });
#
#         function geo_json_dedb2b63ad88f11245b29d7537c2929d_add (data) {
#             geo_json_dedb2b63ad88f11245b29d7537c2929d
#                 .addData(data)
#                 .addTo(map_9421c964426807c99638fd69a882deea);
#         }
#             geo_json_dedb2b63ad88f11245b29d7537c2929d_add({&quot;bbox&quot;: [-87.83, 41.648501, -87.53043115139008, 42.06469333333333], &quot;features&quot;: [{&quot;bbox&quot;: [-87.623772, 41.9010475, -87.623772, 41.9010475], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.623772, 41.9010475], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;363899&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.635185, 41.880317, -87.635185, 41.880317], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.635185, 41.880317], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;236569&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.61728912591934, 41.892592119709725, -87.61728912591934, 41.892592119709725], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.61728912591934, 41.892592119709725], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;159229&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.65884816666667, 41.9396825, -87.65884816666667, 41.9396825], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.65884816666667, 41.9396825], &quot;type&quot;: &quot;Point&quo

# %% [markdown]
# As we can see, we added two new geometry columns "start_point" and "end_point to the gdf_22 Geodataframe:

# %%
gdf_22.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 499470 entries, 0 to 499999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   ride_id                  499470 non-null  object
#  1   rideable_type            499470 non-null  object
#  2   starttime                499470 non-null  datetime64[ns]
#  3   stoptime                 499470 non-null  datetime64[ns]
#  4   from_station_id          499470 non-null  object
#  5   from_station_name        427649 non-null  object
#  6   to_station_id            499470 non-null  object
#  7   to_station_name          423340 non-null  object
#  8   start_lat                499470 non-null  float64
#  9   start_lng                499470 non-null  float64
#  10  end_lat                  499470 non-null  float64
#  11  end_lng                  499470 non-null  float64
#  12  member_casual            499470 non-null  object
#  13  time_difference_seconds  499470 non-null  int64
#  14  tripduration_in_min      499470 non-null  float64
#  15  trip_value               499470 non-null  float64
#  16  start_point              499470 non-null  geometry
#  17  end_point                499470 non-null  geometry
# dtypes: datetime64[ns](2), float64(6), geometry(2), int64(1), object(7)
# memory usage: 72.4+ MB

# %% [markdown]
# ## 3. Lets use the table we created in Notebook 01_get_geodata_districts_chicago.ipynb

# %%
# loading table with the area geometries created in Notebook 01_get_geodata_districts_chicago.ipynb
df_areas = pd.read_csv("data/clean_areas.csv")
df_areas.head(2)
# Out:
#    Unnamed: 0  area_number community_name    shape_area     shape_len  \
# 0           9            1    Rogers Park  5.125990e+07  34052.397576
# 1          19            2     West Ridge  9.842909e+07  43020.689458
#
#                                         new_geometry
# 0  MULTIPOLYGON (((-87.65455590025104 41.99816614...
# 1  MULTIPOLYGON (((-87.6846530946559 42.019484772...

# %%
# converting to GeoDataFrame by using self made function
gdf_areas = sf.to_gdf(df_areas,geometry_column="new_geometry")

# %%
gdf_areas.head()
# Out:
#    Unnamed: 0  area_number  community_name    shape_area     shape_len  \
# 0           9            1     Rogers Park  5.125990e+07  34052.397576
# 1          19            2      West Ridge  9.842909e+07  43020.689458
# 2          30            3          Uptown  6.509564e+07  46972.794555
# 3           5            4  Lincoln Square  7.135233e+07  36624.603085
# 4          47            5    North Center  5.705417e+07  31391.669754
#
#                                         new_geometry
# 0  MULTIPOLYGON (((-87.65456 41.99817, -87.65574 ...
# 1  MULTIPOLYGON (((-87.68465 42.01948, -87.68464 ...
# 2  MULTIPOLYGON (((-87.64102 41.95480, -87.64400 ...
# 3  MULTIPOLYGON (((-87.67441 41.97610, -87.67440 ...
# 4  MULTIPOLYGON (((-87.67336 41.93234, -87.67342 ...

# %% [markdown]
# ## 4. Perform a spatial join, to match points (start/end)  and polygons (districts).

# %% [markdown]
# #### Spatial Join on Start Points

# %%
# setting start_point as gemoetry, so that the starting points are checked (whether they are inside of a district)
gdf_22.set_geometry("start_point", inplace=True)

# %%
# Perform spatial join to match start_points and polygons
gdf_22_merge1 = gpd.tools.sjoin(gdf_22, gdf_areas[["area_number","community_name","new_geometry"]], predicate="within", how='left')

# %% [markdown]
# Renaming the columns "area_number" and "community_name" to "start_area_number" and "start_community_name":

# %%
gdf_22_merge1.rename(columns={"area_number":"start_area_number", "community_name":"start_community_name"},inplace=True)

# %%
gdf_22_merge1.head()
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  9B632EBA1CC3202B  electric_bike 2022-12-07 07:34:57 2022-12-07 07:39:48
# 1  B20C4D0B45751662  electric_bike 2022-04-27 17:09:01 2022-04-27 17:20:53
# 2  F90780236FB6EC9E   classic_bike 2022-06-03 15:31:03 2022-06-03 15:36:42
# 3  98B2B077FE0AFE33  electric_bike 2022-08-29 17:15:10 2022-08-29 17:36:03
# 4  D396D97F3616E948  electric_bike 2022-04-20 07:46:45 2022-04-20 07:50:55
#
#   from_station_id              from_station_name to_station_id  \
# 0    TA1309000019  Lakeview Ave & Fullerton Pkwy             0
# 1             316        Lamon Ave & Belmont Ave             0
# 2           13001   Michigan Ave & Washington St         13008
# 3           13409  Sangamon St & Washington Blvd         20247
# 4          SL-010  Financial Pl & Ida B Wells Dr  TA1309000007
#
#                    to_station_name  start_lat  start_lng  ...    end_lng  \
# 0                             None  41.925656 -87.639104  ... -87.640000
# 1                             None  41.940000 -87.750000  ... -87.720000
# 2                  Millennium Park  41.883984 -87.624684  ... -87.624084
# 3  W Washington Blvd & N Peoria St  41.882971 -87.650839  ... -87.650000
# 4          Franklin St & Monroe St  41.875046 -87.633116  ... -87.635185
#
#    member_casual time_difference_seconds  tripduration_in_min  trip_value  \
# 0         member                     291             4.850000    0.824500
# 1         casual                     712            11.866667    5.984000
# 2         casual                     339             5.650000    1.960500
# 3         member                    1253            20.883333    3.550167
# 4         casual                     250             4.166667    2.750000
#
#                   start_point                   end_point index_right  \
# 0  POINT (-87.63910 41.92566)  POINT (-87.64000 41.92000)         6.0
# 1  POINT (-87.75000 41.94000)  POINT (-87.72000 41.93000)        14.0
# 2  POINT (-87.62468 41.88398)  POINT (-87.62408 41.88103)        31.0
# 3  POINT (-87.65084 41.88297)  POINT (-87.65000 41.88000)        27.0
# 4  POINT (-87.63312 41.87505)  POINT (-87.63519 41.88032)        31.0
#
#    start_area_number  start_community_name
# 0                7.0          Lincoln Park
# 1               15.0          Portage Park
# 2               32.0                  Loop
# 3               28.0        Near West Side
# 4               32.0                  Loop
#
# [5 rows x 21 columns]

# %%
# droping "index_right" column
gdf_22_merge1.drop(columns="index_right",inplace=True)

# %%
# setting end_point as gemoetry, so that the ending points are checked (are they inside of a district (Polygon))
gdf_22_merge1.set_geometry("end_point", inplace=True)

# %%
# Perform spatial join to match points (this time end points)  and polygons (districts)
gdf_22_merge2 = gpd.tools.sjoin(gdf_22_merge1, gdf_areas[["area_number","community_name","new_geometry"]], predicate="within", how='left')

# %%
gdf_22_merge2.head()
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  9B632EBA1CC3202B  electric_bike 2022-12-07 07:34:57 2022-12-07 07:39:48
# 1  B20C4D0B45751662  electric_bike 2022-04-27 17:09:01 2022-04-27 17:20:53
# 2  F90780236FB6EC9E   classic_bike 2022-06-03 15:31:03 2022-06-03 15:36:42
# 3  98B2B077FE0AFE33  electric_bike 2022-08-29 17:15:10 2022-08-29 17:36:03
# 4  D396D97F3616E948  electric_bike 2022-04-20 07:46:45 2022-04-20 07:50:55
#
#   from_station_id              from_station_name to_station_id  \
# 0    TA1309000019  Lakeview Ave & Fullerton Pkwy             0
# 1             316        Lamon Ave & Belmont Ave             0
# 2           13001   Michigan Ave & Washington St         13008
# 3           13409  Sangamon St & Washington Blvd         20247
# 4          SL-010  Financial Pl & Ida B Wells Dr  TA1309000007
#
#                    to_station_name  start_lat  start_lng  ...  \
# 0                             None  41.925656 -87.639104  ...
# 1                             None  41.940000 -87.750000  ...
# 2                  Millennium Park  41.883984 -87.624684  ...
# 3  W Washington Blvd & N Peoria St  41.882971 -87.650839  ...
# 4          Franklin St & Monroe St  41.875046 -87.633116  ...
#
#    time_difference_seconds  tripduration_in_min trip_value  \
# 0                      291             4.850000   0.824500
# 1                      712            11.866667   5.984000
# 2                      339             5.650000   1.960500
# 3                     1253            20.883333   3.550167
# 4                      250             4.166667   2.750000
#
#                   start_point                   end_point  start_area_number  \
# 0  POINT (-87.63910 41.92566)  POINT (-87.64000 41.92000)                7.0
# 1  POINT (-87.75000 41.94000)  POINT (-87.72000 41.93000)               15.0
# 2  POINT (-87.62468 41.88398)  POINT (-87.62408 41.88103)               32.0
# 3  POINT (-87.65084 41.88297)  POINT (-87.65000 41.88000)               28.0
# 4  POINT (-87.63312 41.87505)  POINT (-87.63519 41.88032)               32.0
#
#   start_community_name index_right  area_number  community_name
# 0         Lincoln Park         6.0          7.0    Lincoln Park
# 1         Portage Park        21.0         22.0    Logan Square
# 2                 Loop        31.0         32.0            Loop
# 3       Near West Side        27.0         28.0  Near West Side
# 4                 Loop        31.0         32.0            Loop
#
# [5 rows x 23 columns]

# %% [markdown]
# Renaming the columns "area_number" and "community_name" to "start_area_number" and "start_community_name":

# %%
# renaming columns:
gdf_22_merge2.rename(columns={"area_number":"end_area_number", "community_name":"end_community_name"},inplace=True)
gdf_22_merge2.head(4)
# Out:
#             ride_id  rideable_type           starttime            stoptime  \
# 0  9B632EBA1CC3202B  electric_bike 2022-12-07 07:34:57 2022-12-07 07:39:48
# 1  B20C4D0B45751662  electric_bike 2022-04-27 17:09:01 2022-04-27 17:20:53
# 2  F90780236FB6EC9E   classic_bike 2022-06-03 15:31:03 2022-06-03 15:36:42
# 3  98B2B077FE0AFE33  electric_bike 2022-08-29 17:15:10 2022-08-29 17:36:03
#
#   from_station_id              from_station_name to_station_id  \
# 0    TA1309000019  Lakeview Ave & Fullerton Pkwy             0
# 1             316        Lamon Ave & Belmont Ave             0
# 2           13001   Michigan Ave & Washington St         13008
# 3           13409  Sangamon St & Washington Blvd         20247
#
#                    to_station_name  start_lat  start_lng  ...  \
# 0                             None  41.925656 -87.639104  ...
# 1                             None  41.940000 -87.750000  ...
# 2                  Millennium Park  41.883984 -87.624684  ...
# 3  W Washington Blvd & N Peoria St  41.882971 -87.650839  ...
#
#    time_difference_seconds  tripduration_in_min trip_value  \
# 0                      291             4.850000   0.824500
# 1                      712            11.866667   5.984000
# 2                      339             5.650000   1.960500
# 3                     1253            20.883333   3.550167
#
#                   start_point                   end_point  start_area_number  \
# 0  POINT (-87.63910 41.92566)  POINT (-87.64000 41.92000)                7.0
# 1  POINT (-87.75000 41.94000)  POINT (-87.72000 41.93000)               15.0
# 2  POINT (-87.62468 41.88398)  POINT (-87.62408 41.88103)               32.0
# 3  POINT (-87.65084 41.88297)  POINT (-87.65000 41.88000)               28.0
#
#   start_community_name index_right  end_area_number end_community_name
# 0         Lincoln Park         6.0              7.0       Lincoln Park
# 1         Portage Park        21.0             22.0       Logan Square
# 2                 Loop        31.0             32.0               Loop
# 3       Near West Side        27.0             28.0     Near West Side
#
# [4 rows x 23 columns]

# %%
# droping "index_right" column
gdf_22_merge2.drop(columns="index_right",inplace=True)

# %% [markdown]
# ### Dealing with NaN Values:
#     - Problem: there are some trips, where we have NaN Values for start and end community area numbers and names. Lets look at them:

# %%
# NaN Values in start_area_number:
gdf_22_merge2["start_area_number"].isna().value_counts()
# Out:
# False    496821
# True       2649
# Name: start_area_number, dtype: int64

# %%
gdf_22_merge2["end_area_number"].isna().value_counts()
# Out:
# False    496499
# True       2971
# Name: end_area_number, dtype: int64

# %% [markdown]
# #### Since we made sure, that all Trips had a start and endpoint, NaN Values in the end_area_number/start_area_number mean, that these trips ended/started outside of the the areas of Divvy. Lets deal with the NaN Values, the following way:
#     - If start_area_number = NaN         ---> 999
#     - If start_community_name = Nan      ---> "not in districts"
#     - end_area_number = NaN              ---> 999
#     - end_community_name                 ---> "not in districts"

# %%
# replacing NaN Values:
gdf_22_merge2["start_area_number"].fillna(999, inplace=True)
gdf_22_merge2["end_area_number"].fillna(999, inplace=True)
gdf_22_merge2["start_community_name"].fillna("not in districts", inplace=True)
gdf_22_merge2["end_community_name"].fillna("not in districts", inplace=True)

# %% [markdown]
# As we can see, there are no more NaN values in those columns:

# %%
gdf_22_merge2["end_area_number"].isna().value_counts()
# Out:
# False    499470
# Name: end_area_number, dtype: int64

# %%
# converting start_area_number and end_area_number from float to integer:
gdf_22_merge2["start_area_number"] = gdf_22_merge2["start_area_number"].astype(int)
gdf_22_merge2["end_area_number"] = gdf_22_merge2["end_area_number"].astype(int)

# %% [markdown]
# Store Copy of gdf_22_merge2:

# %%
gdf_22_final = gdf_22_merge2.copy()

# %% [markdown]
# ## 5. Upload to Sql Database

# %%
# #Push DataFrame to SQL Database:
# table_name = 'trips_20xx_v3'

# df_22_final.to_sql(name=table_name, # Name of SQL table
#                     con=engine, # Engine or connection
#                     if_exists='replace', # Drop the table before inserting new values 
#                     schema=schema, # Use schema that was defined earlier
#                     index=False, # Write DataFrame index as a column
#                     chunksize=5000, # Specify the number of rows in each batch to be written at a time
#                     method='multi') # Pass multiple values in a single INSERT clause
# print(f"The {table_name} table was imported successfully.")

# %% [markdown]
# #### All ending Locations for Trips, which have ended outside of chicago districts:

# %%
gdf_22_final[gdf_22_merge2["end_area_number"]==999]["end_point"].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1226c9ba83159b941636d10ffc8705c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1226c9ba83159b941636d10ffc8705c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1226c9ba83159b941636d10ffc8705c = L.map(
#                 &quot;map_b1226c9ba83159b941636d10ffc8705c&quot;,
#                 {
#                     center: [21.065, -44.07],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b1226c9ba83159b941636d10ffc8705c);
#
#
#
#
#
#             var tile_layer_588421a39863869a691c2524d2576886 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b1226c9ba83159b941636d10ffc8705c);
#
#
#             map_b1226c9ba83159b941636d10ffc8705c.fitBounds(
#                 [[0.0, -88.14], [42.13, 0.0]],
#                 {}
#             );
#
#
#         function geo_json_8be11e4442723d24fa17a62feab72c24_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8be11e4442723d24fa17a62feab72c24_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8be11e4442723d24fa17a62feab72c24_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8be11e4442723d24fa17a62feab72c24_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8be11e4442723d24fa17a62feab72c24_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8be11e4442723d24fa17a62feab72c24.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8be11e4442723d24fa17a62feab72c24_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8be11e4442723d24fa17a62feab72c24 = L.geoJson(null, {
#                 onEachFeature: geo_json_8be11e4442723d24fa17a62feab72c24_onEachFeature,
#
#                 style: geo_json_8be11e4442723d24fa17a62feab72c24_styler,
#                 pointToLayer: geo_json_8be11e4442723d24fa17a62feab72c24_pointToLayer
#         });
#
#         function geo_json_8be11e4442723d24fa17a62feab72c24_add (data) {
#             geo_json_8be11e4442723d24fa17a62feab72c24
#                 .addData(data)
#                 .addTo(map_b1226c9ba83159b941636d10ffc8705c);
#         }
#             geo_json_8be11e4442723d24fa17a62feab72c24_add({&quot;bbox&quot;: [-88.14, 0.0, 0.0, 42.13], &quot;features&quot;: [{&quot;bbox&quot;: [-87.71, 42.02, -87.71, 42.02], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.71, 42.02], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;91&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.58, 41.8, -87.58, 41.8], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.58, 41.8], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;122&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.58, 41.8, -87.58, 41.8], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.58, 41.8], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;503&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.71, 42.0, -87.71, 42.0], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.71, 42.0], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;706&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.71, 42.01, -87.71, 42.01], &quot;geometry&quot;: {&quot;coordinates&quot;: [-87.71, 42.01], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;743
